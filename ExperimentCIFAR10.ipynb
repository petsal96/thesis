# %%
import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.losses import Loss
from tensorflow.keras.layers import Conv2D, Flatten, Dense 
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu, tanh
from tensorflow.keras.initializers import Constant, RandomNormal
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import log_loss
from multiprocessing import Process, Value
from datetime import datetime
import numpy as np
import math
import os
from PIL import Image
from google.colab import drive
import pickle

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def normalized_relu(x):
  return math.sqrt(2) * relu(x)

def normalized_tanh(x):
  return tanh(x) / 0.6279

def build_model(input_size, filter_size, r = 32):
  # define model:
  model = Sequential()
  # add feature extraction layer:
  model.add(Conv2D(r, filter_size, activation = normalized_relu, kernel_initializer = RandomNormal(0, math.sqrt(input_size[-1] / np.prod(input_size))), bias_initializer = Constant(0), bias_constraint = MaxNorm(0), input_shape = input_size))
  model.add(Flatten())
  # add hidden fully connected layer:
  model.add(Dense(r, activation = normalized_relu, kernel_initializer = RandomNormal(0, math.sqrt(1 / model.layers[-1].output_shape[-1])), bias_initializer = Constant(0), bias_constraint = MaxNorm(0)))
  # add output layer:
  model.add(Dense(10))
  return model

# %%
# data:
# !cp /content/drive/MyDrive/cifar10/final.zip /content
# !unzip final.zip
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: final/train/3/644.jpg
#   inflating: final/train/3/645.jpg
#   inflating: final/train/3/646.jpg
#   inflating: final/train/3/647.jpg
#   inflating: final/train/3/648.jpg
#   inflating: final/train/3/649.jpg
#   inflating: final/train/3/65.jpg
#   inflating: final/train/3/650.jpg
#   inflating: final/train/3/651.jpg
#   inflating: final/train/3/652.jpg
#   inflating: final/train/3/653.jpg
#   inflating: final/train/3/654.jpg
#   inflating: final/train/3/655.jpg
#   inflating: final/train/3/656.jpg
#   inflating: final/train/3/657.jpg
#   inflating: final/train/3/658.jpg
#   inflating: final/train/3/659.jpg
#   inflating: final/train/3/66.jpg
#   inflating: final/train/3/660.jpg
#   inflating: final/train/3/661.jpg
#   inflating: final/train/3/662.jpg
#   inflating: final/train/3/663.jpg
#   inflating: final/train/3/664.jpg
#   inflating: final/train/3/665.jpg
#   inflating: final/train/3/666.jpg
#   inflating: final/train/3/667.jpg
#   inflating: final/train/3/668.jpg
#   inflating: final/train/3/669.jpg
#   inflating: final/train/3/67.jpg
#   inflating: final/train/3/670.jpg
#   inflating: final/train/3/671.jpg
#   inflating: final/train/3/672.jpg
#   inflating: final/train/3/673.jpg
#   inflating: final/train/3/674.jpg
#   inflating: final/train/3/675.jpg
#   inflating: final/train/3/676.jpg
#   inflating: final/train/3/677.jpg
#   inflating: final/train/3/678.jpg
#   inflating: final/train/3/679.jpg
#   inflating: final/train/3/68.jpg
#   inflating: final/train/3/680.jpg
#   inflating: final/train/3/681.jpg
#   inflating: final/train/3/682.jpg
#   inflating: final/train/3/683.jpg
#   inflating: final/train/3/684.jpg
#   inflating: final/train/3/685.jpg
#   inflating: final/train/3/686.jpg
#   inflating: final/train/3/687.jpg
#   inflating: final/train/3/688.jpg
#   inflating: final/train/3/689.jpg
#   inflating: final/train/3/69.jpg
#   inflating: final/train/3/690.jpg
#   inflating: final/train/3/691.jpg
#   inflating: final/train/3/692.jpg
#   inflating: final/train/3/693.jpg
#   inflating: final/train/3/694.jpg
#   inflating: final/train/3/695.jpg
#   inflating: final/train/3/696.jpg
#   inflating: final/train/3/697.jpg
#   inflating: final/train/3/698.jpg
#   inflating: final/train/3/699.jpg
#   inflating: final/train/3/7.jpg
#   inflating: final/train/3/70.jpg
#   inflating: final/train/3/700.jpg
#   inflating: final/train/3/701.jpg
#   inflating: final/train/3/702.jpg
#   inflating: final/train/3/703.jpg
#   inflating: final/train/3/704.jpg
#   inflating: final/train/3/705.jpg
#   inflating: final/train/3/706.jpg
#   inflating: final/train/3/707.jpg
#   inflating: final/train/3/708.jpg
#   inflating: final/train/3/709.jpg
#   inflating: final/train/3/71.jpg
#   inflating: final/train/3/710.jpg
#   inflating: final/train/3/711.jpg
#   inflating: final/train/3/712.jpg
#   inflating: final/train/3/713.jpg
#   inflating: final/train/3/714.jpg
#   inflating: final/train/3/715.jpg
#   inflating: final/train/3/716.jpg
#   inflating: final/train/3/717.jpg
#   inflating: final/train/3/718.jpg
#   inflating: final/train/3/719.jpg
#   inflating: final/train/3/72.jpg
#   inflating: final/train/3/720.jpg
#   inflating: final/train/3/721.jpg
#   inflating: final/train/3/722.jpg
#   inflating: final/train/3/723.jpg
#   inflating: final/train/3/724.jpg
#   inflating: final/train/3/725.jpg
#   inflating: final/train/3/726.jpg
#   inflating: final/train/3/727.jpg
#   inflating: final/train/3/728.jpg
#   inflating: final/train/3/729.jpg
#   inflating: final/train/3/73.jpg
#   inflating: final/train/3/730.jpg
#   inflating: final/train/3/731.jpg
#   inflating: final/train/3/732.jpg
#   inflating: final/train/3/733.jpg
#   inflating: final/train/3/734.jpg
#   inflating: final/train/3/735.jpg
#   inflating: final/train/3/736.jpg
#   inflating: final/train/3/737.jpg
#   inflating: final/train/3/738.jpg
#   inflating: final/train/3/739.jpg
#   inflating: final/train/3/74.jpg
#   inflating: final/train/3/740.jpg
#   inflating: final/train/3/741.jpg
#   inflating: final/train/3/742.jpg
#   inflating: final/train/3/743.jpg
#   inflating: final/train/3/744.jpg
#   inflating: final/train/3/745.jpg
#   inflating: final/train/3/746.jpg
#   inflating: final/train/3/747.jpg
#   inflating: final/train/3/748.jpg
#   inflating: final/train/3/749.jpg
#   inflating: final/train/3/75.jpg
#   inflating: final/train/3/750.jpg
#   inflating: final/train/3/751.jpg
#   inflating: final/train/3/752.jpg
#   inflating: final/train/3/753.jpg
#   inflating: final/train/3/754.jpg
#   inflating: final/train/3/755.jpg
#   inflating: final/train/3/756.jpg
#   inflating: final/train/3/757.jpg
#   inflating: final/train/3/758.jpg
#   inflating: final/train/3/759.jpg
#   inflating: final/train/3/76.jpg
#   inflating: final/train/3/760.jpg
#   inflating: final/train/3/761.jpg
#   inflating: final/train/3/762.jpg
#   inflating: final/train/3/763.jpg
#   inflating: final/train/3/764.jpg
#   inflating: final/train/3/765.jpg
#   inflating: final/train/3/766.jpg
#   inflating: final/train/3/767.jpg
#   inflating: final/train/3/768.jpg
#   inflating: final/train/3/769.jpg
#   inflating: final/train/3/77.jpg
#   inflating: final/train/3/770.jpg
#   inflating: final/train/3/771.jpg
#   inflating: final/train/3/772.jpg
#   inflating: final/train/3/773.jpg
#   inflating: final/train/3/774.jpg
#   inflating: final/train/3/775.jpg
#   inflating: final/train/3/776.jpg
#   inflating: final/train/3/777.jpg
#   inflating: final/train/3/778.jpg
#   inflating: final/train/3/779.jpg
#   inflating: final/train/3/78.jpg
#   inflating: final/train/3/780.jpg
#   inflating: final/train/3/781.jpg
#   inflating: final/train/3/782.jpg
#   inflating: final/train/3/783.jpg
#   inflating: final/train/3/784.jpg
#   inflating: final/train/3/785.jpg
#   inflating: final/train/3/786.jpg
#   inflating: final/train/3/787.jpg
#   inflating: final/train/3/788.jpg
#   inflating: final/train/3/789.jpg
#   inflating: final/train/3/79.jpg
#   inflating: final/train/3/790.jpg
#   inflating: final/train/3/791.jpg
#   inflating: final/train/3/792.jpg
#   inflating: final/train/3/793.jpg
#   inflating: final/train/3/794.jpg
#   inflating: final/train/3/795.jpg
#   inflating: final/train/3/796.jpg
#   inflating: final/train/3/797.jpg
#   inflating: final/train/3/798.jpg
#   inflating: final/train/3/799.jpg
#   inflating: final/train/3/8.jpg
#   inflating: final/train/3/80.jpg
#   inflating: final/train/3/81.jpg
#   inflating: final/train/3/82.jpg
#   inflating: final/train/3/83.jpg
#   inflating: final/train/3/84.jpg
#   inflating: final/train/3/85.jpg
#   inflating: final/train/3/86.jpg
#   inflating: final/train/3/87.jpg
#   inflating: final/train/3/88.jpg
#   inflating: final/train/3/89.jpg
#   inflating: final/train/3/9.jpg
#   inflating: final/train/3/90.jpg
#   inflating: final/train/3/91.jpg
#   inflating: final/train/3/92.jpg
#   inflating: final/train/3/93.jpg
#   inflating: final/train/3/94.jpg
#   inflating: final/train/3/95.jpg
#   inflating: final/train/3/96.jpg
#   inflating: final/train/3/97.jpg
#   inflating: final/train/3/98.jpg
#   inflating: final/train/3/99.jpg
#    creating: final/train/4/
#   inflating: final/train/4/0.jpg
#   inflating: final/train/4/1.jpg
#   inflating: final/train/4/10.jpg
#   inflating: final/train/4/100.jpg
#   inflating: final/train/4/101.jpg
#   inflating: final/train/4/102.jpg
#   inflating: final/train/4/103.jpg
#   inflating: final/train/4/104.jpg
#   inflating: final/train/4/105.jpg
#   inflating: final/train/4/106.jpg
#   inflating: final/train/4/107.jpg
#   inflating: final/train/4/108.jpg
#   inflating: final/train/4/109.jpg
#   inflating: final/train/4/11.jpg
#   inflating: final/train/4/110.jpg
#   inflating: final/train/4/111.jpg
#   inflating: final/train/4/112.jpg
#   inflating: final/train/4/113.jpg
#   inflating: final/train/4/114.jpg
#   inflating: final/train/4/115.jpg
#   inflating: final/train/4/116.jpg
#   inflating: final/train/4/117.jpg
#   inflating: final/train/4/118.jpg
#   inflating: final/train/4/119.jpg
#   inflating: final/train/4/12.jpg
#   inflating: final/train/4/120.jpg
#   inflating: final/train/4/121.jpg
#   inflating: final/train/4/122.jpg
#   inflating: final/train/4/123.jpg
#   inflating: final/train/4/124.jpg
#   inflating: final/train/4/125.jpg
#   inflating: final/train/4/126.jpg
#   inflating: final/train/4/127.jpg
#   inflating: final/train/4/128.jpg
#   inflating: final/train/4/129.jpg
#   inflating: final/train/4/13.jpg
#   inflating: final/train/4/130.jpg
#   inflating: final/train/4/131.jpg
#   inflating: final/train/4/132.jpg
#   inflating: final/train/4/133.jpg
#   inflating: final/train/4/134.jpg
#   inflating: final/train/4/135.jpg
#   inflating: final/train/4/136.jpg
#   inflating: final/train/4/137.jpg
#   inflating: final/train/4/138.jpg
#   inflating: final/train/4/139.jpg
#   inflating: final/train/4/14.jpg
#   inflating: final/train/4/140.jpg
#   inflating: final/train/4/141.jpg
#   inflating: final/train/4/142.jpg
#   inflating: final/train/4/143.jpg
#   inflating: final/train/4/144.jpg
#   inflating: final/train/4/145.jpg
#   inflating: final/train/4/146.jpg
#   inflating: final/train/4/147.jpg
#   inflating: final/train/4/148.jpg
#   inflating: final/train/4/149.jpg
#   inflating: final/train/4/15.jpg
#   inflating: final/train/4/150.jpg
#   inflating: final/train/4/151.jpg
#   inflating: final/train/4/152.jpg
#   inflating: final/train/4/153.jpg
#   inflating: final/train/4/154.jpg
#   inflating: final/train/4/155.jpg
#   inflating: final/train/4/156.jpg
#   inflating: final/train/4/157.jpg
#   inflating: final/train/4/158.jpg
#   inflating: final/train/4/159.jpg
#   inflating: final/train/4/16.jpg
#   inflating: final/train/4/160.jpg
#   inflating: final/train/4/161.jpg
#   inflating: final/train/4/162.jpg
#   inflating: final/train/4/163.jpg
#   inflating: final/train/4/164.jpg
#   inflating: final/train/4/165.jpg
#   inflating: final/train/4/166.jpg
#   inflating: final/train/4/167.jpg
#   inflating: final/train/4/168.jpg
#   inflating: final/train/4/169.jpg
#   inflating: final/train/4/17.jpg
#   inflating: final/train/4/170.jpg
#   inflating: final/train/4/171.jpg
#   inflating: final/train/4/172.jpg
#   inflating: final/train/4/173.jpg
#   inflating: final/train/4/174.jpg
#   inflating: final/train/4/175.jpg
#   inflating: final/train/4/176.jpg
#   inflating: final/train/4/177.jpg
#   inflating: final/train/4/178.jpg
#   inflating: final/train/4/179.jpg
#   inflating: final/train/4/18.jpg
#   inflating: final/train/4/180.jpg
#   inflating: final/train/4/181.jpg
#   inflating: final/train/4/182.jpg
#   inflating: final/train/4/183.jpg
#   inflating: final/train/4/184.jpg
#   inflating: final/train/4/185.jpg
#   inflating: final/train/4/186.jpg
#   inflating: final/train/4/187.jpg
#   inflating: final/train/4/188.jpg
#   inflating: final/train/4/189.jpg
#   inflating: final/train/4/19.jpg
#   inflating: final/train/4/190.jpg
#   inflating: final/train/4/191.jpg
#   inflating: final/train/4/192.jpg
#   inflating: final/train/4/193.jpg
#   inflating: final/train/4/194.jpg
#   inflating: final/train/4/195.jpg
#   inflating: final/train/4/196.jpg
#   inflating: final/train/4/197.jpg
#   inflating: final/train/4/198.jpg
#   inflating: final/train/4/199.jpg
#   inflating: final/train/4/2.jpg
#   inflating: final/train/4/20.jpg
#   inflating: final/train/4/200.jpg
#   inflating: final/train/4/201.jpg
#   inflating: final/train/4/202.jpg
#   inflating: final/train/4/203.jpg
#   inflating: final/train/4/204.jpg
#   inflating: final/train/4/205.jpg
#   inflating: final/train/4/206.jpg
#   inflating: final/train/4/207.jpg
#   inflating: final/train/4/208.jpg
#   inflating: final/train/4/209.jpg
#   inflating: final/train/4/21.jpg
#   inflating: final/train/4/210.jpg
#   inflating: final/train/4/211.jpg
#   inflating: final/train/4/212.jpg
#   inflating: final/train/4/213.jpg
#   inflating: final/train/4/214.jpg
#   inflating: final/train/4/215.jpg
#   inflating: final/train/4/216.jpg
#   inflating: final/train/4/217.jpg
#   inflating: final/train/4/218.jpg
#   inflating: final/train/4/219.jpg
#   inflating: final/train/4/22.jpg
#   inflating: final/train/4/220.jpg
#   inflating: final/train/4/221.jpg
#   inflating: final/train/4/222.jpg
#   inflating: final/train/4/223.jpg
#   inflating: final/train/4/224.jpg
#   inflating: final/train/4/225.jpg
#   inflating: final/train/4/226.jpg
#   inflating: final/train/4/227.jpg
#   inflating: final/train/4/228.jpg
#   inflating: final/train/4/229.jpg
#   inflating: final/train/4/23.jpg
#   inflating: final/train/4/230.jpg
#   inflating: final/train/4/231.jpg
#   inflating: final/train/4/232.jpg
#   inflating: final/train/4/233.jpg
#   inflating: final/train/4/234.jpg
#   inflating: final/train/4/235.jpg
#   inflating: final/train/4/236.jpg
#   inflating: final/train/4/237.jpg
#   inflating: final/train/4/238.jpg
#   inflating: final/train/4/239.jpg
#   inflating: final/train/4/24.jpg
#   inflating: final/train/4/240.jpg
#   inflating: final/train/4/241.jpg
#   inflating: final/train/4/242.jpg
#   inflating: final/train/4/243.jpg
#   inflating: final/train/4/244.jpg
#   inflating: final/train/4/245.jpg
#   inflating: final/train/4/246.jpg
#   inflating: final/train/4/247.jpg
#   inflating: final/train/4/248.jpg
#   inflating: final/train/4/249.jpg
#   inflating: final/train/4/25.jpg
#   inflating: final/train/4/250.jpg
#   inflating: final/train/4/251.jpg
#   inflating: final/train/4/252.jpg
#   inflating: final/train/4/253.jpg
#   inflating: final/train/4/254.jpg
#   inflating: final/train/4/255.jpg
#   inflating: final/train/4/256.jpg
#   inflating: final/train/4/257.jpg
#   inflating: final/train/4/258.jpg
#   inflating: final/train/4/259.jpg
#   inflating: final/train/4/26.jpg
#   inflating: final/train/4/260.jpg
#   inflating: final/train/4/261.jpg
#   inflating: final/train/4/262.jpg
#   inflating: final/train/4/263.jpg
#   inflating: final/train/4/264.jpg
#   inflating: final/train/4/265.jpg
#   inflating: final/train/4/266.jpg
#   inflating: final/train/4/267.jpg
#   inflating: final/train/4/268.jpg
#   inflating: final/train/4/269.jpg
#   inflating: final/train/4/27.jpg
#   inflating: final/train/4/270.jpg
#   inflating: final/train/4/271.jpg
#   inflating: final/train/4/272.jpg
#   inflating: final/train/4/273.jpg
#   inflating: final/train/4/274.jpg
#   inflating: final/train/4/275.jpg
#   inflating: final/train/4/276.jpg
#   inflating: final/train/4/277.jpg
#   inflating: final/train/4/278.jpg
#   inflating: final/train/4/279.jpg
#   inflating: final/train/4/28.jpg
#   inflating: final/train/4/280.jpg
#   inflating: final/train/4/281.jpg
#   inflating: final/train/4/282.jpg
#   inflating: final/train/4/283.jpg
#   inflating: final/train/4/284.jpg
#   inflating: final/train/4/285.jpg
#   inflating: final/train/4/286.jpg
#   inflating: final/train/4/287.jpg
#   inflating: final/train/4/288.jpg
#   inflating: final/train/4/289.jpg
#   inflating: final/train/4/29.jpg
#   inflating: final/train/4/290.jpg
#   inflating: final/train/4/291.jpg
#   inflating: final/train/4/292.jpg
#   inflating: final/train/4/293.jpg
#   inflating: final/train/4/294.jpg
#   inflating: final/train/4/295.jpg
#   inflating: final/train/4/296.jpg
#   inflating: final/train/4/297.jpg
#   inflating: final/train/4/298.jpg
#   inflating: final/train/4/299.jpg
#   inflating: final/train/4/3.jpg
#   inflating: final/train/4/30.jpg
#   inflating: final/train/4/300.jpg
#   inflating: final/train/4/301.jpg
#   inflating: final/train/4/302.jpg
#   inflating: final/train/4/303.jpg
#   inflating: final/train/4/304.jpg
#   inflating: final/train/4/305.jpg
#   inflating: final/train/4/306.jpg
#   inflating: final/train/4/307.jpg
#   inflating: final/train/4/308.jpg
#   inflating: final/train/4/309.jpg
#   inflating: final/train/4/31.jpg
#   inflating: final/train/4/310.jpg
#   inflating: final/train/4/311.jpg
#   inflating: final/train/4/312.jpg
#   inflating: final/train/4/313.jpg
#   inflating: final/train/4/314.jpg
#   inflating: final/train/4/315.jpg
#   inflating: final/train/4/316.jpg
#   inflating: final/train/4/317.jpg
#   inflating: final/train/4/318.jpg
#   inflating: final/train/4/319.jpg
#   inflating: final/train/4/32.jpg
#   inflating: final/train/4/320.jpg
#   inflating: final/train/4/321.jpg
#   inflating: final/train/4/322.jpg
#   inflating: final/train/4/323.jpg
#   inflating: final/train/4/324.jpg
#   inflating: final/train/4/325.jpg
#   inflating: final/train/4/326.jpg
#   inflating: final/train/4/327.jpg
#   inflating: final/train/4/328.jpg
#   inflating: final/train/4/329.jpg
#   inflating: final/train/4/33.jpg
#   inflating: final/train/4/330.jpg
#   inflating: final/train/4/331.jpg
#   inflating: final/train/4/332.jpg
#   inflating: final/train/4/333.jpg
#   inflating: final/train/4/334.jpg
#   inflating: final/train/4/335.jpg
#   inflating: final/train/4/336.jpg
#   inflating: final/train/4/337.jpg
#   inflating: final/train/4/338.jpg
#   inflating: final/train/4/339.jpg
#   inflating: final/train/4/34.jpg
#   inflating: final/train/4/340.jpg
#   inflating: final/train/4/341.jpg
#   inflating: final/train/4/342.jpg
#   inflating: final/train/4/343.jpg
#   inflating: final/train/4/344.jpg
#   inflating: final/train/4/345.jpg
#   inflating: final/train/4/346.jpg
#   inflating: final/train/4/347.jpg
#   inflating: final/train/4/348.jpg
#   inflating: final/train/4/349.jpg
#   inflating: final/train/4/35.jpg
#   inflating: final/train/4/350.jpg
#   inflating: final/train/4/351.jpg
#   inflating: final/train/4/352.jpg
#   inflating: final/train/4/353.jpg
#   inflating: final/train/4/354.jpg
#   inflating: final/train/4/355.jpg
#   inflating: final/train/4/356.jpg
#   inflating: final/train/4/357.jpg
#   inflating: final/train/4/358.jpg
#   inflating: final/train/4/359.jpg
#   inflating: final/train/4/36.jpg
#   inflating: final/train/4/360.jpg
#   inflating: final/train/4/361.jpg
#   inflating: final/train/4/362.jpg
#   inflating: final/train/4/363.jpg
#   inflating: final/train/4/364.jpg
#   inflating: final/train/4/365.jpg
#   inflating: final/train/4/366.jpg
#   inflating: final/train/4/367.jpg
#   inflating: final/train/4/368.jpg
#   inflating: final/train/4/369.jpg
#   inflating: final/train/4/37.jpg
#   inflating: final/train/4/370.jpg
#   inflating: final/train/4/371.jpg
#   inflating: final/train/4/372.jpg
#   inflating: final/train/4/373.jpg
#   inflating: final/train/4/374.jpg
#   inflating: final/train/4/375.jpg
#   inflating: final/train/4/376.jpg
#   inflating: final/train/4/377.jpg
#   inflating: final/train/4/378.jpg
#   inflating: final/train/4/379.jpg
#   inflating: final/train/4/38.jpg
#   inflating: final/train/4/380.jpg
#   inflating: final/train/4/381.jpg
#   inflating: final/train/4/382.jpg
#   inflating: final/train/4/383.jpg
#   inflating: final/train/4/384.jpg
#   inflating: final/train/4/385.jpg
#   inflating: final/train/4/386.jpg
#   inflating: final/train/4/387.jpg
#   inflating: final/train/4/388.jpg
#   inflating: final/train/4/389.jpg
#   inflating: final/train/4/39.jpg
#   inflating: final/train/4/390.jpg
#   inflating: final/train/4/391.jpg
#   inflating: final/train/4/392.jpg
#   inflating: final/train/4/393.jpg
#   inflating: final/train/4/394.jpg
#   inflating: final/train/4/395.jpg
#   inflating: final/train/4/396.jpg
#   inflating: final/train/4/397.jpg
#   inflating: final/train/4/398.jpg
#   inflating: final/train/4/399.jpg
#   inflating: final/train/4/4.jpg
#   inflating: final/train/4/40.jpg
#   inflating: final/train/4/400.jpg
#   inflating: final/train/4/401.jpg
#   inflating: final/train/4/402.jpg
#   inflating: final/train/4/403.jpg
#   inflating: final/train/4/404.jpg
#   inflating: final/train/4/405.jpg
#   inflating: final/train/4/406.jpg
#   inflating: final/train/4/407.jpg
#   inflating: final/train/4/408.jpg
#   inflating: final/train/4/409.jpg
#   inflating: final/train/4/41.jpg
#   inflating: final/train/4/410.jpg
#   inflating: final/train/4/411.jpg
#   inflating: final/train/4/412.jpg
#   inflating: final/train/4/413.jpg
#   inflating: final/train/4/414.jpg
#   inflating: final/train/4/415.jpg
#   inflating: final/train/4/416.jpg
#   inflating: final/train/4/417.jpg
#   inflating: final/train/4/418.jpg
#   inflating: final/train/4/419.jpg
#   inflating: final/train/4/42.jpg
#   inflating: final/train/4/420.jpg
#   inflating: final/train/4/421.jpg
#   inflating: final/train/4/422.jpg
#   inflating: final/train/4/423.jpg
#   inflating: final/train/4/424.jpg
#   inflating: final/train/4/425.jpg
#   inflating: final/train/4/426.jpg
#   inflating: final/train/4/427.jpg
#   inflating: final/train/4/428.jpg
#   inflating: final/train/4/429.jpg
#   inflating: final/train/4/43.jpg
#   inflating: final/train/4/430.jpg
#   inflating: final/train/4/431.jpg
#   inflating: final/train/4/432.jpg
#   inflating: final/train/4/433.jpg
#   inflating: final/train/4/434.jpg
#   inflating: final/train/4/435.jpg
#   inflating: final/train/4/436.jpg
#   inflating: final/train/4/437.jpg
#   inflating: final/train/4/438.jpg
#   inflating: final/train/4/439.jpg
#   inflating: final/train/4/44.jpg
#   inflating: final/train/4/440.jpg
#   inflating: final/train/4/441.jpg
#   inflating: final/train/4/442.jpg
#   inflating: final/train/4/443.jpg
#   inflating: final/train/4/444.jpg
#   inflating: final/train/4/445.jpg
#   inflating: final/train/4/446.jpg
#   inflating: final/train/4/447.jpg
#   inflating: final/train/4/448.jpg
#   inflating: final/train/4/449.jpg
#   inflating: final/train/4/45.jpg
#   inflating: final/train/4/450.jpg
#   inflating: final/train/4/451.jpg
#   inflating: final/train/4/452.jpg
#   inflating: final/train/4/453.jpg
#   inflating: final/train/4/454.jpg
#   inflating: final/train/4/455.jpg
#   inflating: final/train/4/456.jpg
#   inflating: final/train/4/457.jpg
#   inflating: final/train/4/458.jpg
#   inflating: final/train/4/459.jpg
#   inflating: final/train/4/46.jpg
#   inflating: final/train/4/460.jpg
#   inflating: final/train/4/461.jpg
#   inflating: final/train/4/462.jpg
#   inflating: final/train/4/463.jpg
#   inflating: final/train/4/464.jpg
#   inflating: final/train/4/465.jpg
#   inflating: final/train/4/466.jpg
#   inflating: final/train/4/467.jpg
#   inflating: final/train/4/468.jpg
#   inflating: final/train/4/469.jpg
#   inflating: final/train/4/47.jpg
#   inflating: final/train/4/470.jpg
#   inflating: final/train/4/471.jpg
#   inflating: final/train/4/472.jpg
#   inflating: final/train/4/473.jpg
#   inflating: final/train/4/474.jpg
#   inflating: final/train/4/475.jpg
#   inflating: final/train/4/476.jpg
#   inflating: final/train/4/477.jpg
#   inflating: final/train/4/478.jpg
#   inflating: final/train/4/479.jpg
#   inflating: final/train/4/48.jpg
#   inflating: final/train/4/480.jpg
#   inflating: final/train/4/481.jpg
#   inflating: final/train/4/482.jpg
#   inflating: final/train/4/483.jpg
#   inflating: final/train/4/484.jpg
#   inflating: final/train/4/485.jpg
#   inflating: final/train/4/486.jpg
#   inflating: final/train/4/487.jpg
#   inflating: final/train/4/488.jpg
#   inflating: final/train/4/489.jpg
#   inflating: final/train/4/49.jpg
#   inflating: final/train/4/490.jpg
#   inflating: final/train/4/491.jpg
#   inflating: final/train/4/492.jpg
#   inflating: final/train/4/493.jpg
#   inflating: final/train/4/494.jpg
#   inflating: final/train/4/495.jpg
#   inflating: final/train/4/496.jpg
#   inflating: final/train/4/497.jpg
#   inflating: final/train/4/498.jpg
#   inflating: final/train/4/499.jpg
#   inflating: final/train/4/5.jpg
#   inflating: final/train/4/50.jpg
#   inflating: final/train/4/500.jpg
#   inflating: final/train/4/501.jpg
#   inflating: final/train/4/502.jpg
#   inflating: final/train/4/503.jpg
#   inflating: final/train/4/504.jpg
#   inflating: final/train/4/505.jpg
#   inflating: final/train/4/506.jpg
#   inflating: final/train/4/507.jpg
#   inflating: final/train/4/508.jpg
#   inflating: final/train/4/509.jpg
#   inflating: final/train/4/51.jpg
#   inflating: final/train/4/510.jpg
#   inflating: final/train/4/511.jpg
#   inflating: final/train/4/512.jpg
#   inflating: final/train/4/513.jpg
#   inflating: final/train/4/514.jpg
#   inflating: final/train/4/515.jpg
#   inflating: final/train/4/516.jpg
#   inflating: final/train/4/517.jpg
#   inflating: final/train/4/518.jpg
#   inflating: final/train/4/519.jpg
#   inflating: final/train/4/52.jpg
#   inflating: final/train/4/520.jpg
#   inflating: final/train/4/521.jpg
#   inflating: final/train/4/522.jpg
#   inflating: final/train/4/523.jpg
#   inflating: final/train/4/524.jpg
#   inflating: final/train/4/525.jpg
#   inflating: final/train/4/526.jpg
#   inflating: final/train/4/527.jpg
#   inflating: final/train/4/528.jpg
#   inflating: final/train/4/529.jpg
#   inflating: final/train/4/53.jpg
#   inflating: final/train/4/530.jpg
#   inflating: final/train/4/531.jpg
#   inflating: final/train/4/532.jpg
#   inflating: final/train/4/533.jpg
#   inflating: final/train/4/534.jpg
#   inflating: final/train/4/535.jpg
#   inflating: final/train/4/536.jpg
#   inflating: final/train/4/537.jpg
#   inflating: final/train/4/538.jpg
#   inflating: final/train/4/539.jpg
#   inflating: final/train/4/54.jpg
#   inflating: final/train/4/540.jpg
#   inflating: final/train/4/541.jpg
#   inflating: final/train/4/542.jpg
#   inflating: final/train/4/543.jpg
#   inflating: final/train/4/544.jpg
#   inflating: final/train/4/545.jpg
#   inflating: final/train/4/546.jpg
#   inflating: final/train/4/547.jpg
#   inflating: final/train/4/548.jpg
#   inflating: final/train/4/549.jpg
#   inflating: final/train/4/55.jpg
#   inflating: final/train/4/550.jpg
#   inflating: final/train/4/551.jpg
#   inflating: final/train/4/552.jpg
#   inflating: final/train/4/553.jpg
#   inflating: final/train/4/554.jpg
#   inflating: final/train/4/555.jpg
#   inflating: final/train/4/556.jpg
#   inflating: final/train/4/557.jpg
#   inflating: final/train/4/558.jpg
#   inflating: final/train/4/559.jpg
#   inflating: final/train/4/56.jpg
#   inflating: final/train/4/560.jpg
#   inflating: final/train/4/561.jpg
#   inflating: final/train/4/562.jpg
#   inflating: final/train/4/563.jpg
#   inflating: final/train/4/564.jpg
#   inflating: final/train/4/565.jpg
#   inflating: final/train/4/566.jpg
#   inflating: final/train/4/567.jpg
#   inflating: final/train/4/568.jpg
#   inflating: final/train/4/569.jpg
#   inflating: final/train/4/57.jpg
#   inflating: final/train/4/570.jpg
#   inflating: final/train/4/571.jpg
#   inflating: final/train/4/572.jpg
#   inflating: final/train/4/573.jpg
#   inflating: final/train/4/574.jpg
#   inflating: final/train/4/575.jpg
#   inflating: final/train/4/576.jpg
#   inflating: final/train/4/577.jpg
#   inflating: final/train/4/578.jpg
#   inflating: final/train/4/579.jpg
#   inflating: final/train/4/58.jpg
#   inflating: final/train/4/580.jpg
#   inflating: final/train/4/581.jpg
#   inflating: final/train/4/582.jpg
#   inflating: final/train/4/583.jpg
#   inflating: final/train/4/584.jpg
#   inflating: final/train/4/585.jpg
#   inflating: final/train/4/586.jpg
#   inflating: final/train/4/587.jpg
#   inflating: final/train/4/588.jpg
#   inflating: final/train/4/589.jpg
#   inflating: final/train/4/59.jpg
#   inflating: final/train/4/590.jpg
#   inflating: final/train/4/591.jpg
#   inflating: final/train/4/592.jpg
#   inflating: final/train/4/593.jpg
#   inflating: final/train/4/594.jpg
#   inflating: final/train/4/595.jpg
#   inflating: final/train/4/596.jpg
#   inflating: final/train/4/597.jpg
#   inflating: final/train/4/598.jpg
#   inflating: final/train/4/599.jpg
#   inflating: final/train/4/6.jpg
#   inflating: final/train/4/60.jpg
#   inflating: final/train/4/600.jpg
#   inflating: final/train/4/601.jpg
#   inflating: final/train/4/602.jpg
#   inflating: final/train/4/603.jpg
#   inflating: final/train/4/604.jpg
#   inflating: final/train/4/605.jpg
#   inflating: final/train/4/606.jpg
#   inflating: final/train/4/607.jpg
#   inflating: final/train/4/608.jpg
#   inflating: final/train/4/609.jpg
#   inflating: final/train/4/61.jpg
#   inflating: final/train/4/610.jpg
#   inflating: final/train/4/611.jpg
#   inflating: final/train/4/612.jpg
#   inflating: final/train/4/613.jpg
#   inflating: final/train/4/614.jpg
#   inflating: final/train/4/615.jpg
#   inflating: final/train/4/616.jpg
#   inflating: final/train/4/617.jpg
#   inflating: final/train/4/618.jpg
#   inflating: final/train/4/619.jpg
#   inflating: final/train/4/62.jpg
#   inflating: final/train/4/620.jpg
#   inflating: final/train/4/621.jpg
#   inflating: final/train/4/622.jpg
#   inflating: final/train/4/623.jpg
#   inflating: final/train/4/624.jpg
#   inflating: final/train/4/625.jpg
#   inflating: final/train/4/626.jpg
#   inflating: final/train/4/627.jpg
#   inflating: final/train/4/628.jpg
#   inflating: final/train/4/629.jpg
#   inflating: final/train/4/63.jpg
#   inflating: final/train/4/630.jpg
#   inflating: final/train/4/631.jpg
#   inflating: final/train/4/632.jpg
#   inflating: final/train/4/633.jpg
#   inflating: final/train/4/634.jpg
#   inflating: final/train/4/635.jpg
#   inflating: final/train/4/636.jpg
#   inflating: final/train/4/637.jpg
#   inflating: final/train/4/638.jpg
#   inflating: final/train/4/639.jpg
#   inflating: final/train/4/64.jpg
#   inflating: final/train/4/640.jpg
#   inflating: final/train/4/641.jpg
#   inflating: final/train/4/642.jpg
#   inflating: final/train/4/643.jpg
#   inflating: final/train/4/644.jpg
#   inflating: final/train/4/645.jpg
#   inflating: final/train/4/646.jpg
#   inflating: final/train/4/647.jpg
#   inflating: final/train/4/648.jpg
#   inflating: final/train/4/649.jpg
#   inflating: final/train/4/65.jpg
#   inflating: final/train/4/650.jpg
#   inflating: final/train/4/651.jpg
#   inflating: final/train/4/652.jpg
#   inflating: final/train/4/653.jpg
#   inflating: final/train/4/654.jpg
#   inflating: final/train/4/655.jpg
#   inflating: final/train/4/656.jpg
#   inflating: final/train/4/657.jpg
#   inflating: final/train/4/658.jpg
#   inflating: final/train/4/659.jpg
#   inflating: final/train/4/66.jpg
#   inflating: final/train/4/660.jpg
#   inflating: final/train/4/661.jpg
#   inflating: final/train/4/662.jpg
#   inflating: final/train/4/663.jpg
#   inflating: final/train/4/664.jpg
#   inflating: final/train/4/665.jpg
#   inflating: final/train/4/666.jpg
#   inflating: final/train/4/667.jpg
#   inflating: final/train/4/668.jpg
#   inflating: final/train/4/669.jpg
#   inflating: final/train/4/67.jpg
#   inflating: final/train/4/670.jpg
#   inflating: final/train/4/671.jpg
#   inflating: final/train/4/672.jpg
#   inflating: final/train/4/673.jpg
#   inflating: final/train/4/674.jpg
#   inflating: final/train/4/675.jpg
#   inflating: final/train/4/676.jpg
#   inflating: final/train/4/677.jpg
#   inflating: final/train/4/678.jpg
#   inflating: final/train/4/679.jpg
#   inflating: final/train/4/68.jpg
#   inflating: final/train/4/680.jpg
#   inflating: final/train/4/681.jpg
#   inflating: final/train/4/682.jpg
#   inflating: final/train/4/683.jpg
#   inflating: final/train/4/684.jpg
#   inflating: final/train/4/685.jpg
#   inflating: final/train/4/686.jpg
#   inflating: final/train/4/687.jpg
#   inflating: final/train/4/688.jpg
#   inflating: final/train/4/689.jpg
#   inflating: final/train/4/69.jpg
#   inflating: final/train/4/690.jpg
#   inflating: final/train/4/691.jpg
#   inflating: final/train/4/692.jpg
#   inflating: final/train/4/693.jpg
#   inflating: final/train/4/694.jpg
#   inflating: final/train/4/695.jpg
#   inflating: final/train/4/696.jpg
#   inflating: final/train/4/697.jpg
#   inflating: final/train/4/698.jpg
#   inflating: final/train/4/699.jpg
#   inflating: final/train/4/7.jpg
#   inflating: final/train/4/70.jpg
#   inflating: final/train/4/700.jpg
#   inflating: final/train/4/701.jpg
#   inflating: final/train/4/702.jpg
#   inflating: final/train/4/703.jpg
#   inflating: final/train/4/704.jpg
#   inflating: final/train/4/705.jpg
#   inflating: final/train/4/706.jpg
#   inflating: final/train/4/707.jpg
#   inflating: final/train/4/708.jpg
#   inflating: final/train/4/709.jpg
#   inflating: final/train/4/71.jpg
#   inflating: final/train/4/710.jpg
#   inflating: final/train/4/711.jpg
#   inflating: final/train/4/712.jpg
#   inflating: final/train/4/713.jpg
#   inflating: final/train/4/714.jpg
#   inflating: final/train/4/715.jpg
#   inflating: final/train/4/716.jpg
#   inflating: final/train/4/717.jpg
#   inflating: final/train/4/718.jpg
#   inflating: final/train/4/719.jpg
#   inflating: final/train/4/72.jpg
#   inflating: final/train/4/720.jpg
#   inflating: final/train/4/721.jpg
#   inflating: final/train/4/722.jpg
#   inflating: final/train/4/723.jpg
#   inflating: final/train/4/724.jpg
#   inflating: final/train/4/725.jpg
#   inflating: final/train/4/726.jpg
#   inflating: final/train/4/727.jpg
#   inflating: final/train/4/728.jpg
#   inflating: final/train/4/729.jpg
#   inflating: final/train/4/73.jpg
#   inflating: final/train/4/730.jpg
#   inflating: final/train/4/731.jpg
#   inflating: final/train/4/732.jpg
#   inflating: final/train/4/733.jpg
#   inflating: final/train/4/734.jpg
#   inflating: final/train/4/735.jpg
#   inflating: final/train/4/736.jpg
#   inflating: final/train/4/737.jpg
#   inflating: final/train/4/738.jpg
#   inflating: final/train/4/739.jpg
#   inflating: final/train/4/74.jpg
#   inflating: final/train/4/740.jpg
#   inflating: final/train/4/741.jpg
#   inflating: final/train/4/742.jpg
#   inflating: final/train/4/743.jpg
#   inflating: final/train/4/744.jpg
#   inflating: final/train/4/745.jpg
#   inflating: final/train/4/746.jpg
#   inflating: final/train/4/747.jpg
#   inflating: final/train/4/748.jpg
#   inflating: final/train/4/749.jpg
#   inflating: final/train/4/75.jpg
#   inflating: final/train/4/750.jpg
#   inflating: final/train/4/751.jpg
#   inflating: final/train/4/752.jpg
#   inflating: final/train/4/753.jpg
#   inflating: final/train/4/754.jpg
#   inflating: final/train/4/755.jpg
#   inflating: final/train/4/756.jpg
#   inflating: final/train/4/757.jpg
#   inflating: final/train/4/758.jpg
#   inflating: final/train/4/759.jpg
#   inflating: final/train/4/76.jpg
#   inflating: final/train/4/760.jpg
#   inflating: final/train/4/761.jpg
#   inflating: final/train/4/762.jpg
#   inflating: final/train/4/763.jpg
#   inflating: final/train/4/764.jpg
#   inflating: final/train/4/765.jpg
#   inflating: final/train/4/766.jpg
#   inflating: final/train/4/767.jpg
#   inflating: final/train/4/768.jpg
#   inflating: final/train/4/769.jpg
#   inflating: final/train/4/77.jpg
#   inflating: final/train/4/770.jpg
#   inflating: final/train/4/771.jpg
#   inflating: final/train/4/772.jpg
#   inflating: final/train/4/773.jpg
#   inflating: final/train/4/774.jpg
#   inflating: final/train/4/775.jpg
#   inflating: final/train/4/776.jpg
#   inflating: final/train/4/777.jpg
#   inflating: final/train/4/778.jpg
#   inflating: final/train/4/779.jpg
#   inflating: final/train/4/78.jpg
#   inflating: final/train/4/780.jpg
#   inflating: final/train/4/781.jpg
#   inflating: final/train/4/782.jpg
#   inflating: final/train/4/783.jpg
#   inflating: final/train/4/784.jpg
#   inflating: final/train/4/785.jpg
#   inflating: final/train/4/786.jpg
#   inflating: final/train/4/787.jpg
#   inflating: final/train/4/788.jpg
#   inflating: final/train/4/789.jpg
#   inflating: final/train/4/79.jpg
#   inflating: final/train/4/790.jpg
#   inflating: final/train/4/791.jpg
#   inflating: final/train/4/792.jpg
#   inflating: final/train/4/793.jpg
#   inflating: final/train/4/794.jpg
#   inflating: final/train/4/795.jpg
#   inflating: final/train/4/796.jpg
#   inflating: final/train/4/797.jpg
#   inflating: final/train/4/798.jpg
#   inflating: final/train/4/799.jpg
#   inflating: final/train/4/8.jpg
#   inflating: final/train/4/80.jpg
#   inflating: final/train/4/81.jpg
#   inflating: final/train/4/82.jpg
#   inflating: final/train/4/83.jpg
#   inflating: final/train/4/84.jpg
#   inflating: final/train/4/85.jpg
#   inflating: final/train/4/86.jpg
#   inflating: final/train/4/87.jpg
#   inflating: final/train/4/88.jpg
#   inflating: final/train/4/89.jpg
#   inflating: final/train/4/9.jpg
#   inflating: final/train/4/90.jpg
#   inflating: final/train/4/91.jpg
#   inflating: final/train/4/92.jpg
#   inflating: final/train/4/93.jpg
#   inflating: final/train/4/94.jpg
#   inflating: final/train/4/95.jpg
#   inflating: final/train/4/96.jpg
#   inflating: final/train/4/97.jpg
#   inflating: final/train/4/98.jpg
#   inflating: final/train/4/99.jpg
#    creating: final/train/5/
#   inflating: final/train/5/0.jpg
#   inflating: final/train/5/1.jpg
#   inflating: final/train/5/10.jpg
#   inflating: final/train/5/100.jpg
#   inflating: final/train/5/101.jpg
#   inflating: final/train/5/102.jpg
#   inflating: final/train/5/103.jpg
#   inflating: final/train/5/104.jpg
#   inflating: final/train/5/105.jpg
#   inflating: final/train/5/106.jpg
#   inflating: final/train/5/107.jpg
#   inflating: final/train/5/108.jpg
#   inflating: final/train/5/109.jpg
#   inflating: final/train/5/11.jpg
#   inflating: final/train/5/110.jpg
#   inflating: final/train/5/111.jpg
#   inflating: final/train/5/112.jpg
#   inflating: final/train/5/113.jpg
#   inflating: final/train/5/114.jpg
#   inflating: final/train/5/115.jpg
#   inflating: final/train/5/116.jpg
#   inflating: final/train/5/117.jpg
#   inflating: final/train/5/118.jpg
#   inflating: final/train/5/119.jpg
#   inflating: final/train/5/12.jpg
#   inflating: final/train/5/120.jpg
#   inflating: final/train/5/121.jpg
#   inflating: final/train/5/122.jpg
#   inflating: final/train/5/123.jpg
#   inflating: final/train/5/124.jpg
#   inflating: final/train/5/125.jpg
#   inflating: final/train/5/126.jpg
#   inflating: final/train/5/127.jpg
#   inflating: final/train/5/128.jpg
#   inflating: final/train/5/129.jpg
#   inflating: final/train/5/13.jpg
#   inflating: final/train/5/130.jpg
#   inflating: final/train/5/131.jpg
#   inflating: final/train/5/132.jpg
#   inflating: final/train/5/133.jpg
#   inflating: final/train/5/134.jpg
#   inflating: final/train/5/135.jpg
#   inflating: final/train/5/136.jpg
#   inflating: final/train/5/137.jpg
#   inflating: final/train/5/138.jpg
#   inflating: final/train/5/139.jpg
#   inflating: final/train/5/14.jpg
#   inflating: final/train/5/140.jpg
#   inflating: final/train/5/141.jpg
#   inflating: final/train/5/142.jpg
#   inflating: final/train/5/143.jpg
#   inflating: final/train/5/144.jpg
#   inflating: final/train/5/145.jpg
#   inflating: final/train/5/146.jpg
#   inflating: final/train/5/147.jpg
#   inflating: final/train/5/148.jpg
#   inflating: final/train/5/149.jpg
#   inflating: final/train/5/15.jpg
#   inflating: final/train/5/150.jpg
#   inflating: final/train/5/151.jpg
#   inflating: final/train/5/152.jpg
#   inflating: final/train/5/153.jpg
#   inflating: final/train/5/154.jpg
#   inflating: final/train/5/155.jpg
#   inflating: final/train/5/156.jpg
#   inflating: final/train/5/157.jpg
#   inflating: final/train/5/158.jpg
#   inflating: final/train/5/159.jpg
#   inflating: final/train/5/16.jpg
#   inflating: final/train/5/160.jpg
#   inflating: final/train/5/161.jpg
#   inflating: final/train/5/162.jpg
#   inflating: final/train/5/163.jpg
#   inflating: final/train/5/164.jpg
#   inflating: final/train/5/165.jpg
#   inflating: final/train/5/166.jpg
#   inflating: final/train/5/167.jpg
#   inflating: final/train/5/168.jpg
#   inflating: final/train/5/169.jpg
#   inflating: final/train/5/17.jpg
#   inflating: final/train/5/170.jpg
#   inflating: final/train/5/171.jpg
#   inflating: final/train/5/172.jpg
#   inflating: final/train/5/173.jpg
#   inflating: final/train/5/174.jpg
#   inflating: final/train/5/175.jpg
#   inflating: final/train/5/176.jpg
#   inflating: final/train/5/177.jpg
#   inflating: final/train/5/178.jpg
#   inflating: final/train/5/179.jpg
#   inflating: final/train/5/18.jpg
#   inflating: final/train/5/180.jpg
#   inflating: final/train/5/181.jpg
#   inflating: final/train/5/182.jpg
#   inflating: final/train/5/183.jpg
#   inflating: final/train/5/184.jpg
#   inflating: final/train/5/185.jpg
#   inflating: final/train/5/186.jpg
#   inflating: final/train/5/187.jpg
#   inflating: final/train/5/188.jpg
#   inflating: final/train/5/189.jpg
#   inflating: final/train/5/19.jpg
#   inflating: final/train/5/190.jpg
#   inflating: final/train/5/191.jpg
#   inflating: final/train/5/192.jpg
#   inflating: final/train/5/193.jpg
#   inflating: final/train/5/194.jpg
#   inflating: final/train/5/195.jpg
#   inflating: final/train/5/196.jpg
#   inflating: final/train/5/197.jpg
#   inflating: final/train/5/198.jpg
#   inflating: final/train/5/199.jpg
#   inflating: final/train/5/2.jpg
#   inflating: final/train/5/20.jpg
#   inflating: final/train/5/200.jpg
#   inflating: final/train/5/201.jpg
#   inflating: final/train/5/202.jpg
#   inflating: final/train/5/203.jpg
#   inflating: final/train/5/204.jpg
#   inflating: final/train/5/205.jpg
#   inflating: final/train/5/206.jpg
#   inflating: final/train/5/207.jpg
#   inflating: final/train/5/208.jpg
#   inflating: final/train/5/209.jpg
#   inflating: final/train/5/21.jpg
#   inflating: final/train/5/210.jpg
#   inflating: final/train/5/211.jpg
#   inflating: final/train/5/212.jpg
#   inflating: final/train/5/213.jpg
#   inflating: final/train/5/214.jpg
#   inflating: final/train/5/215.jpg
#   inflating: final/train/5/216.jpg
#   inflating: final/train/5/217.jpg
#   inflating: final/train/5/218.jpg
#   inflating: final/train/5/219.jpg
#   inflating: final/train/5/22.jpg
#   inflating: final/train/5/220.jpg
#   inflating: final/train/5/221.jpg
#   inflating: final/train/5/222.jpg
#   inflating: final/train/5/223.jpg
#   inflating: final/train/5/224.jpg
#   inflating: final/train/5/225.jpg
#   inflating: final/train/5/226.jpg
#   inflating: final/train/5/227.jpg
#   inflating: final/train/5/228.jpg
#   inflating: final/train/5/229.jpg
#   inflating: final/train/5/23.jpg
#   inflating: final/train/5/230.jpg
#   inflating: final/train/5/231.jpg
#   inflating: final/train/5/232.jpg
#   inflating: final/train/5/233.jpg
#   inflating: final/train/5/234.jpg
#   inflating: final/train/5/235.jpg
#   inflating: final/train/5/236.jpg
#   inflating: final/train/5/237.jpg
#   inflating: final/train/5/238.jpg
#   inflating: final/train/5/239.jpg
#   inflating: final/train/5/24.jpg
#   inflating: final/train/5/240.jpg
#   inflating: final/train/5/241.jpg
#   inflating: final/train/5/242.jpg
#   inflating: final/train/5/243.jpg
#   inflating: final/train/5/244.jpg
#   inflating: final/train/5/245.jpg
#   inflating: final/train/5/246.jpg
#   inflating: final/train/5/247.jpg
#   inflating: final/train/5/248.jpg
#   inflating: final/train/5/249.jpg
#   inflating: final/train/5/25.jpg
#   inflating: final/train/5/250.jpg
#   inflating: final/train/5/251.jpg
#   inflating: final/train/5/252.jpg
#   inflating: final/train/5/253.jpg
#   inflating: final/train/5/254.jpg
#   inflating: final/train/5/255.jpg
#   inflating: final/train/5/256.jpg
#   inflating: final/train/5/257.jpg
#   inflating: final/train/5/258.jpg
#   inflating: final/train/5/259.jpg
#   inflating: final/train/5/26.jpg
#   inflating: final/train/5/260.jpg
#   inflating: final/train/5/261.jpg
#   inflating: final/train/5/262.jpg
#   inflating: final/train/5/263.jpg
#   inflating: final/train/5/264.jpg
#   inflating: final/train/5/265.jpg
#   inflating: final/train/5/266.jpg
#   inflating: final/train/5/267.jpg
#   inflating: final/train/5/268.jpg
#   inflating: final/train/5/269.jpg
#   inflating: final/train/5/27.jpg
#   inflating: final/train/5/270.jpg
#   inflating: final/train/5/271.jpg
#   inflating: final/train/5/272.jpg
#   inflating: final/train/5/273.jpg
#   inflating: final/train/5/274.jpg
#   inflating: final/train/5/275.jpg
#   inflating: final/train/5/276.jpg
#   inflating: final/train/5/277.jpg
#   inflating: final/train/5/278.jpg
#   inflating: final/train/5/279.jpg
#   inflating: final/train/5/28.jpg
#   inflating: final/train/5/280.jpg
#   inflating: final/train/5/281.jpg
#   inflating: final/train/5/282.jpg
#   inflating: final/train/5/283.jpg
#   inflating: final/train/5/284.jpg
#   inflating: final/train/5/285.jpg
#   inflating: final/train/5/286.jpg
#   inflating: final/train/5/287.jpg
#   inflating: final/train/5/288.jpg
#   inflating: final/train/5/289.jpg
#   inflating: final/train/5/29.jpg
#   inflating: final/train/5/290.jpg
#   inflating: final/train/5/291.jpg
#   inflating: final/train/5/292.jpg
#   inflating: final/train/5/293.jpg
#   inflating: final/train/5/294.jpg
#   inflating: final/train/5/295.jpg
#   inflating: final/train/5/296.jpg
#   inflating: final/train/5/297.jpg
#   inflating: final/train/5/298.jpg
#   inflating: final/train/5/299.jpg
#   inflating: final/train/5/3.jpg
#   inflating: final/train/5/30.jpg
#   inflating: final/train/5/300.jpg
#   inflating: final/train/5/301.jpg
#   inflating: final/train/5/302.jpg
#   inflating: final/train/5/303.jpg
#   inflating: final/train/5/304.jpg
#   inflating: final/train/5/305.jpg
#   inflating: final/train/5/306.jpg
#   inflating: final/train/5/307.jpg
#   inflating: final/train/5/308.jpg
#   inflating: final/train/5/309.jpg
#   inflating: final/train/5/31.jpg
#   inflating: final/train/5/310.jpg
#   inflating: final/train/5/311.jpg
#   inflating: final/train/5/312.jpg
#   inflating: final/train/5/313.jpg
#   inflating: final/train/5/314.jpg
#   inflating: final/train/5/315.jpg
#   inflating: final/train/5/316.jpg
#   inflating: final/train/5/317.jpg
#   inflating: final/train/5/318.jpg
#   inflating: final/train/5/319.jpg
#   inflating: final/train/5/32.jpg
#   inflating: final/train/5/320.jpg
#   inflating: final/train/5/321.jpg
#   inflating: final/train/5/322.jpg
#   inflating: final/train/5/323.jpg
#   inflating: final/train/5/324.jpg
#   inflating: final/train/5/325.jpg
#   inflating: final/train/5/326.jpg
#   inflating: final/train/5/327.jpg
#   inflating: final/train/5/328.jpg
#   inflating: final/train/5/329.jpg
#   inflating: final/train/5/33.jpg
#   inflating: final/train/5/330.jpg
#   inflating: final/train/5/331.jpg
#   inflating: final/train/5/332.jpg
#   inflating: final/train/5/333.jpg
#   inflating: final/train/5/334.jpg
#   inflating: final/train/5/335.jpg
#   inflating: final/train/5/336.jpg
# ...
#   inflating: final/train/9/44.jpg
#   inflating: final/train/9/440.jpg
#   inflating: final/train/9/441.jpg
#   inflating: final/train/9/442.jpg
#   inflating: final/train/9/443.jpg
#   inflating: final/train/9/444.jpg
#   inflating: final/train/9/445.jpg
#   inflating: final/train/9/446.jpg
#   inflating: final/train/9/447.jpg
#   inflating: final/train/9/448.jpg
#   inflating: final/train/9/449.jpg
#   inflating: final/train/9/45.jpg
#   inflating: final/train/9/450.jpg
#   inflating: final/train/9/451.jpg
#   inflating: final/train/9/452.jpg
#   inflating: final/train/9/453.jpg
#   inflating: final/train/9/454.jpg
#   inflating: final/train/9/455.jpg
#   inflating: final/train/9/456.jpg
#   inflating: final/train/9/457.jpg
#   inflating: final/train/9/458.jpg
#   inflating: final/train/9/459.jpg
#   inflating: final/train/9/46.jpg
#   inflating: final/train/9/460.jpg
#   inflating: final/train/9/461.jpg
#   inflating: final/train/9/462.jpg
#   inflating: final/train/9/463.jpg
#   inflating: final/train/9/464.jpg
#   inflating: final/train/9/465.jpg
#   inflating: final/train/9/466.jpg
#   inflating: final/train/9/467.jpg
#   inflating: final/train/9/468.jpg
#   inflating: final/train/9/469.jpg
#   inflating: final/train/9/47.jpg
#   inflating: final/train/9/470.jpg
#   inflating: final/train/9/471.jpg
#   inflating: final/train/9/472.jpg
#   inflating: final/train/9/473.jpg
#   inflating: final/train/9/474.jpg
#   inflating: final/train/9/475.jpg
#   inflating: final/train/9/476.jpg
#   inflating: final/train/9/477.jpg
#   inflating: final/train/9/478.jpg
#   inflating: final/train/9/479.jpg
#   inflating: final/train/9/48.jpg
#   inflating: final/train/9/480.jpg
#   inflating: final/train/9/481.jpg
#   inflating: final/train/9/482.jpg
#   inflating: final/train/9/483.jpg
#   inflating: final/train/9/484.jpg
#   inflating: final/train/9/485.jpg
#   inflating: final/train/9/486.jpg
#   inflating: final/train/9/487.jpg
#   inflating: final/train/9/488.jpg
#   inflating: final/train/9/489.jpg
#   inflating: final/train/9/49.jpg
#   inflating: final/train/9/490.jpg
#   inflating: final/train/9/491.jpg
#   inflating: final/train/9/492.jpg
#   inflating: final/train/9/493.jpg
#   inflating: final/train/9/494.jpg
#   inflating: final/train/9/495.jpg
#   inflating: final/train/9/496.jpg
#   inflating: final/train/9/497.jpg
#   inflating: final/train/9/498.jpg
#   inflating: final/train/9/499.jpg
#   inflating: final/train/9/5.jpg
#   inflating: final/train/9/50.jpg
#   inflating: final/train/9/500.jpg
#   inflating: final/train/9/501.jpg
#   inflating: final/train/9/502.jpg
#   inflating: final/train/9/503.jpg
#   inflating: final/train/9/504.jpg
#   inflating: final/train/9/505.jpg
#   inflating: final/train/9/506.jpg
#   inflating: final/train/9/507.jpg
#   inflating: final/train/9/508.jpg
#   inflating: final/train/9/509.jpg
#   inflating: final/train/9/51.jpg
#   inflating: final/train/9/510.jpg
#   inflating: final/train/9/511.jpg
#   inflating: final/train/9/512.jpg
#   inflating: final/train/9/513.jpg
#   inflating: final/train/9/514.jpg
#   inflating: final/train/9/515.jpg
#   inflating: final/train/9/516.jpg
#   inflating: final/train/9/517.jpg
#   inflating: final/train/9/518.jpg
#   inflating: final/train/9/519.jpg
#   inflating: final/train/9/52.jpg
#   inflating: final/train/9/520.jpg
#   inflating: final/train/9/521.jpg
#   inflating: final/train/9/522.jpg
#   inflating: final/train/9/523.jpg
#   inflating: final/train/9/524.jpg
#   inflating: final/train/9/525.jpg
#   inflating: final/train/9/526.jpg
#   inflating: final/train/9/527.jpg
#   inflating: final/train/9/528.jpg
#   inflating: final/train/9/529.jpg
#   inflating: final/train/9/53.jpg
#   inflating: final/train/9/530.jpg
#   inflating: final/train/9/531.jpg
#   inflating: final/train/9/532.jpg
#   inflating: final/train/9/533.jpg
#   inflating: final/train/9/534.jpg
#   inflating: final/train/9/535.jpg
#   inflating: final/train/9/536.jpg
#   inflating: final/train/9/537.jpg
#   inflating: final/train/9/538.jpg
#   inflating: final/train/9/539.jpg
#   inflating: final/train/9/54.jpg
#   inflating: final/train/9/540.jpg
#   inflating: final/train/9/541.jpg
#   inflating: final/train/9/542.jpg
#   inflating: final/train/9/543.jpg
#   inflating: final/train/9/544.jpg
#   inflating: final/train/9/545.jpg
#   inflating: final/train/9/546.jpg
#   inflating: final/train/9/547.jpg
#   inflating: final/train/9/548.jpg
#   inflating: final/train/9/549.jpg
#   inflating: final/train/9/55.jpg
#   inflating: final/train/9/550.jpg
#   inflating: final/train/9/551.jpg
#   inflating: final/train/9/552.jpg
#   inflating: final/train/9/553.jpg
#   inflating: final/train/9/554.jpg
#   inflating: final/train/9/555.jpg
#   inflating: final/train/9/556.jpg
#   inflating: final/train/9/557.jpg
#   inflating: final/train/9/558.jpg
#   inflating: final/train/9/559.jpg
#   inflating: final/train/9/56.jpg
#   inflating: final/train/9/560.jpg
#   inflating: final/train/9/561.jpg
#   inflating: final/train/9/562.jpg
#   inflating: final/train/9/563.jpg
#   inflating: final/train/9/564.jpg
#   inflating: final/train/9/565.jpg
#   inflating: final/train/9/566.jpg
#   inflating: final/train/9/567.jpg
#   inflating: final/train/9/568.jpg
#   inflating: final/train/9/569.jpg
#   inflating: final/train/9/57.jpg
#   inflating: final/train/9/570.jpg
#   inflating: final/train/9/571.jpg
#   inflating: final/train/9/572.jpg
#   inflating: final/train/9/573.jpg
#   inflating: final/train/9/574.jpg
#   inflating: final/train/9/575.jpg
#   inflating: final/train/9/576.jpg
#   inflating: final/train/9/577.jpg
#   inflating: final/train/9/578.jpg
#   inflating: final/train/9/579.jpg
#   inflating: final/train/9/58.jpg
#   inflating: final/train/9/580.jpg
#   inflating: final/train/9/581.jpg
#   inflating: final/train/9/582.jpg
#   inflating: final/train/9/583.jpg
#   inflating: final/train/9/584.jpg
#   inflating: final/train/9/585.jpg
#   inflating: final/train/9/586.jpg
#   inflating: final/train/9/587.jpg
#   inflating: final/train/9/588.jpg
#   inflating: final/train/9/589.jpg
#   inflating: final/train/9/59.jpg
#   inflating: final/train/9/590.jpg
#   inflating: final/train/9/591.jpg
#   inflating: final/train/9/592.jpg
#   inflating: final/train/9/593.jpg
#   inflating: final/train/9/594.jpg
#   inflating: final/train/9/595.jpg
#   inflating: final/train/9/596.jpg
#   inflating: final/train/9/597.jpg
#   inflating: final/train/9/598.jpg
#   inflating: final/train/9/599.jpg
#   inflating: final/train/9/6.jpg
#   inflating: final/train/9/60.jpg
#   inflating: final/train/9/600.jpg
#   inflating: final/train/9/601.jpg
#   inflating: final/train/9/602.jpg
#   inflating: final/train/9/603.jpg
#   inflating: final/train/9/604.jpg
#   inflating: final/train/9/605.jpg
#   inflating: final/train/9/606.jpg
#   inflating: final/train/9/607.jpg
#   inflating: final/train/9/608.jpg
#   inflating: final/train/9/609.jpg
#   inflating: final/train/9/61.jpg
#   inflating: final/train/9/610.jpg
#   inflating: final/train/9/611.jpg
#   inflating: final/train/9/612.jpg
#   inflating: final/train/9/613.jpg
#   inflating: final/train/9/614.jpg
#   inflating: final/train/9/615.jpg
#   inflating: final/train/9/616.jpg
#   inflating: final/train/9/617.jpg
#   inflating: final/train/9/618.jpg
#   inflating: final/train/9/619.jpg
#   inflating: final/train/9/62.jpg
#   inflating: final/train/9/620.jpg
#   inflating: final/train/9/621.jpg
#   inflating: final/train/9/622.jpg
#   inflating: final/train/9/623.jpg
#   inflating: final/train/9/624.jpg
#   inflating: final/train/9/625.jpg
#   inflating: final/train/9/626.jpg
#   inflating: final/train/9/627.jpg
#   inflating: final/train/9/628.jpg
#   inflating: final/train/9/629.jpg
#   inflating: final/train/9/63.jpg
#   inflating: final/train/9/630.jpg
#   inflating: final/train/9/631.jpg
#   inflating: final/train/9/632.jpg
#   inflating: final/train/9/633.jpg
#   inflating: final/train/9/634.jpg
#   inflating: final/train/9/635.jpg
#   inflating: final/train/9/636.jpg
#   inflating: final/train/9/637.jpg
#   inflating: final/train/9/638.jpg
#   inflating: final/train/9/639.jpg
#   inflating: final/train/9/64.jpg
#   inflating: final/train/9/640.jpg
#   inflating: final/train/9/641.jpg
#   inflating: final/train/9/642.jpg
#   inflating: final/train/9/643.jpg
#   inflating: final/train/9/644.jpg
#   inflating: final/train/9/645.jpg
#   inflating: final/train/9/646.jpg
#   inflating: final/train/9/647.jpg
#   inflating: final/train/9/648.jpg
#   inflating: final/train/9/649.jpg
#   inflating: final/train/9/65.jpg
#   inflating: final/train/9/650.jpg
#   inflating: final/train/9/651.jpg
#   inflating: final/train/9/652.jpg
#   inflating: final/train/9/653.jpg
#   inflating: final/train/9/654.jpg
#   inflating: final/train/9/655.jpg
#   inflating: final/train/9/656.jpg
#   inflating: final/train/9/657.jpg
#   inflating: final/train/9/658.jpg
#   inflating: final/train/9/659.jpg
#   inflating: final/train/9/66.jpg
#   inflating: final/train/9/660.jpg
#   inflating: final/train/9/661.jpg
#   inflating: final/train/9/662.jpg
#   inflating: final/train/9/663.jpg
#   inflating: final/train/9/664.jpg
#   inflating: final/train/9/665.jpg
#   inflating: final/train/9/666.jpg
#   inflating: final/train/9/667.jpg
#   inflating: final/train/9/668.jpg
#   inflating: final/train/9/669.jpg
#   inflating: final/train/9/67.jpg
#   inflating: final/train/9/670.jpg
#   inflating: final/train/9/671.jpg
#   inflating: final/train/9/672.jpg
#   inflating: final/train/9/673.jpg
#   inflating: final/train/9/674.jpg
#   inflating: final/train/9/675.jpg
#   inflating: final/train/9/676.jpg
#   inflating: final/train/9/677.jpg
#   inflating: final/train/9/678.jpg
#   inflating: final/train/9/679.jpg
#   inflating: final/train/9/68.jpg
#   inflating: final/train/9/680.jpg
#   inflating: final/train/9/681.jpg
#   inflating: final/train/9/682.jpg
#   inflating: final/train/9/683.jpg
#   inflating: final/train/9/684.jpg
#   inflating: final/train/9/685.jpg
#   inflating: final/train/9/686.jpg
#   inflating: final/train/9/687.jpg
#   inflating: final/train/9/688.jpg
#   inflating: final/train/9/689.jpg
#   inflating: final/train/9/69.jpg
#   inflating: final/train/9/690.jpg
#   inflating: final/train/9/691.jpg
#   inflating: final/train/9/692.jpg
#   inflating: final/train/9/693.jpg
#   inflating: final/train/9/694.jpg
#   inflating: final/train/9/695.jpg
#   inflating: final/train/9/696.jpg
#   inflating: final/train/9/697.jpg
#   inflating: final/train/9/698.jpg
#   inflating: final/train/9/699.jpg
#   inflating: final/train/9/7.jpg
#   inflating: final/train/9/70.jpg
#   inflating: final/train/9/700.jpg
#   inflating: final/train/9/701.jpg
#   inflating: final/train/9/702.jpg
#   inflating: final/train/9/703.jpg
#   inflating: final/train/9/704.jpg
#   inflating: final/train/9/705.jpg
#   inflating: final/train/9/706.jpg
#   inflating: final/train/9/707.jpg
#   inflating: final/train/9/708.jpg
#   inflating: final/train/9/709.jpg
#   inflating: final/train/9/71.jpg
#   inflating: final/train/9/710.jpg
#   inflating: final/train/9/711.jpg
#   inflating: final/train/9/712.jpg
#   inflating: final/train/9/713.jpg
#   inflating: final/train/9/714.jpg
#   inflating: final/train/9/715.jpg
#   inflating: final/train/9/716.jpg
#   inflating: final/train/9/717.jpg
#   inflating: final/train/9/718.jpg
#   inflating: final/train/9/719.jpg
#   inflating: final/train/9/72.jpg
#   inflating: final/train/9/720.jpg
#   inflating: final/train/9/721.jpg
#   inflating: final/train/9/722.jpg
#   inflating: final/train/9/723.jpg
#   inflating: final/train/9/724.jpg
#   inflating: final/train/9/725.jpg
#   inflating: final/train/9/726.jpg
#   inflating: final/train/9/727.jpg
#   inflating: final/train/9/728.jpg
#   inflating: final/train/9/729.jpg
#   inflating: final/train/9/73.jpg
#   inflating: final/train/9/730.jpg
#   inflating: final/train/9/731.jpg
#   inflating: final/train/9/732.jpg
#   inflating: final/train/9/733.jpg
#   inflating: final/train/9/734.jpg
#   inflating: final/train/9/735.jpg
#   inflating: final/train/9/736.jpg
#   inflating: final/train/9/737.jpg
#   inflating: final/train/9/738.jpg
#   inflating: final/train/9/739.jpg
#   inflating: final/train/9/74.jpg
#   inflating: final/train/9/740.jpg
#   inflating: final/train/9/741.jpg
#   inflating: final/train/9/742.jpg
#   inflating: final/train/9/743.jpg
#   inflating: final/train/9/744.jpg
#   inflating: final/train/9/745.jpg
#   inflating: final/train/9/746.jpg
#   inflating: final/train/9/747.jpg
#   inflating: final/train/9/748.jpg
#   inflating: final/train/9/749.jpg
#   inflating: final/train/9/75.jpg
#   inflating: final/train/9/750.jpg
#   inflating: final/train/9/751.jpg
#   inflating: final/train/9/752.jpg
#   inflating: final/train/9/753.jpg
#   inflating: final/train/9/754.jpg
#   inflating: final/train/9/755.jpg
#   inflating: final/train/9/756.jpg
#   inflating: final/train/9/757.jpg
#   inflating: final/train/9/758.jpg
#   inflating: final/train/9/759.jpg
#   inflating: final/train/9/76.jpg
#   inflating: final/train/9/760.jpg
#   inflating: final/train/9/761.jpg
#   inflating: final/train/9/762.jpg
#   inflating: final/train/9/763.jpg
#   inflating: final/train/9/764.jpg
#   inflating: final/train/9/765.jpg
#   inflating: final/train/9/766.jpg
#   inflating: final/train/9/767.jpg
#   inflating: final/train/9/768.jpg
#   inflating: final/train/9/769.jpg
#   inflating: final/train/9/77.jpg
#   inflating: final/train/9/770.jpg
#   inflating: final/train/9/771.jpg
#   inflating: final/train/9/772.jpg
#   inflating: final/train/9/773.jpg
#   inflating: final/train/9/774.jpg
#   inflating: final/train/9/775.jpg
#   inflating: final/train/9/776.jpg
#   inflating: final/train/9/777.jpg
#   inflating: final/train/9/778.jpg
#   inflating: final/train/9/779.jpg
#   inflating: final/train/9/78.jpg
#   inflating: final/train/9/780.jpg
#   inflating: final/train/9/781.jpg
#   inflating: final/train/9/782.jpg
#   inflating: final/train/9/783.jpg
#   inflating: final/train/9/784.jpg
#   inflating: final/train/9/785.jpg
#   inflating: final/train/9/786.jpg
#   inflating: final/train/9/787.jpg
#   inflating: final/train/9/788.jpg
#   inflating: final/train/9/789.jpg
#   inflating: final/train/9/79.jpg
#   inflating: final/train/9/790.jpg
#   inflating: final/train/9/791.jpg
#   inflating: final/train/9/792.jpg
#   inflating: final/train/9/793.jpg
#   inflating: final/train/9/794.jpg
#   inflating: final/train/9/795.jpg
#   inflating: final/train/9/796.jpg
#   inflating: final/train/9/797.jpg
#   inflating: final/train/9/798.jpg
#   inflating: final/train/9/799.jpg
#   inflating: final/train/9/8.jpg
#   inflating: final/train/9/80.jpg
#   inflating: final/train/9/81.jpg
#   inflating: final/train/9/82.jpg
#   inflating: final/train/9/83.jpg
#   inflating: final/train/9/84.jpg
#   inflating: final/train/9/85.jpg
#   inflating: final/train/9/86.jpg
#   inflating: final/train/9/87.jpg
#   inflating: final/train/9/88.jpg
#   inflating: final/train/9/89.jpg
#   inflating: final/train/9/9.jpg
#   inflating: final/train/9/90.jpg
#   inflating: final/train/9/91.jpg
#   inflating: final/train/9/92.jpg
#   inflating: final/train/9/93.jpg
#   inflating: final/train/9/94.jpg
#   inflating: final/train/9/95.jpg
#   inflating: final/train/9/96.jpg
#   inflating: final/train/9/97.jpg
#   inflating: final/train/9/98.jpg
#   inflating: final/train/9/99.jpg

# %%
# input transformation:
img_size = (32, 32)
def load_data(root_dir):
  images, labels = [], []
  current_label = 0
  for subdir, dirs, files in os.walk(root_dir):
    if subdir == root_dir:
      continue
    label = int(os.path.basename(os.path.normpath(subdir)))
    for file in files:
      img = Image.open(os.path.join(subdir, file))
      img = img.convert("L")
      img = img.resize(img_size)
      img = np.asarray(img)
      img = img[..., None]
      images.append(img)
      labels.append(label)
  images = np.array(images)
  labels = np.array(labels)
  return images, labels

def sphere_transformation(data):
    trans_data = np.empty(data.shape[0:-1] + (data.shape[-1] + 1,))
    trans_data[..., 0] = np.cos(data[..., 0])
    for i in range(1, data.shape[-1]):
        trans_data[..., i] = np.prod(np.sin(data[..., :i]), axis = -1) * np.cos(data[..., i])
    trans_data[..., -1] = np.prod(np.sin(data), axis = -1)
    return trans_data

train_images, train_labels = load_data("final/train")
test_images, test_labels = load_data("final/test")

train_images, test_images = (2 * train_images / 255.0 - 1) * math.pi, (2 * test_images / 255.0 - 1) * math.pi

train_images = sphere_transformation(train_images)
test_images = sphere_transformation(test_images)

# %%
# setups:
input_size = train_images[0].shape
filter_sizes = ((2, 2), (3, 3), (5, 5), (9, 9), (16, 16))
n_folds = 5
epochs = 500

# hyperparams:
batch_sizes = (16, 32, 64)
decay_epochs = (10, 25, 50, 100, 150, 200, 300, 500)
Cs = (1E-3, 1E-2, 1E-1, 1, 1E+1, 1E+2, 1E+3)

# %%
# read current results:
if os.path.exists("/content/drive/MyDrive/CIFAR10relu.pickle"):
  with open("/content/drive/MyDrive/CIFAR10relu.pickle", "rb") as file:
    results = pickle.load(file)
else:
  results = {}
  folds = StratifiedKFold(n_splits = n_folds, shuffle = True)
  splits = [(train, val) for (train, val) in folds.split(train_images, train_labels)]
  results["HYP_LAST_LOSSES"] = []
  results["HYP_LAST_SPLITS"] = splits
  results["HYP_LAST_TIME"] = 0
  results["HYP_FULL_LOSSES"] = []
  results["HYP_FULL_SPLITS"] = splits
  results["HYP_FULL_TIME"] = 0
  results["LAST_LOSSES"] = []
  results["LAST_TIME"] = 0
  results["FULL_LOSSES"] = []
  results["FULL_TIME"] = 0

# %%
# learning rate scheduler:
max_lr = 1E-2
min_lr = 1E-5
def lr_decay(epoch, lr, epochs, max_lr, min_lr):
  if epoch == 0:
    return lr
  decay = (min_lr / max_lr) ** (1 / (epochs - 1))
  if lr * decay > min_lr:
    lr *= decay
  return lr

# full model evaluation:
def full_model_eval(input_size, filter_size, train_images, train_labels, test_images, test_labels, de, bs, test_loss, test_accuracy): 
  # split training set:
  X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, stratify = train_labels, test_size = 0.25)
  # train model:
  full_model = build_model(input_size, filter_size)
  full_model.compile(optimizer = SGD(learning_rate = max_lr), loss = SparseCategoricalCrossentropy(from_logits = True), metrics = ["accuracy"])
  full_model.fit(X_train, y_train, epochs = epochs, batch_size = bs, validation_data = (X_val, y_val), callbacks = [EarlyStopping(monitor = "val_loss", min_delta = 0.001, patience = 10, restore_best_weights = True), LearningRateScheduler(lambda epoch, lr: lr_decay(epoch, lr, de, max_lr, min_lr))], verbose = 0)
  # evaluate on test set:
  test_loss.value, test_accuracy.value = full_model.evaluate(test_images, test_labels, verbose = 0)

# last layer model evaluation:
def last_layer_eval(input_size, filter_size, train_images, train_labels, test_images, test_labels, C, test_loss, test_accuracy): 
  # train model:
  last_layer_model = build_model(input_size, filter_size)
  last_layer_model = Model(inputs = last_layer_model.input, outputs = last_layer_model.layers[-2].output)
  X_train = last_layer_model.predict(train_images, verbose = 0)
  y_train = np.squeeze(train_labels)
  pipe = make_pipeline(StandardScaler(), LogisticRegression(C = C, fit_intercept = False, max_iter = 10000, verbose = 0))
  pipe.fit(X_train, y_train)
  # evaluate on test set:
  X_test = last_layer_model.predict(test_images, verbose = 0)
  y_test = np.squeeze(test_labels)
  probs_test = pipe.predict_proba(X_test)
  test_loss.value = log_loss(y_test, probs_test)
  test_accuracy.value = pipe.score(X_test, y_test)

# %%
for i, (train, val) in enumerate(results["HYP_LAST_SPLITS"]):

  if len(results["HYP_LAST_LOSSES"]) <= i:
    results["HYP_LAST_LOSSES"].append([])

  for j, filter_size in enumerate(filter_sizes):

    if len(results["HYP_LAST_LOSSES"][i]) <= j:
      results["HYP_LAST_LOSSES"][i].append([])

    # train last layer models:
    for k, C in enumerate(Cs):

      if len(results["HYP_LAST_LOSSES"][i][j]) > k:
        continue

      before = datetime.now()
      loss = Value("d", math.inf)
      accuracy = Value("d", 0.)
      p = Process(target = last_layer_eval, args = (input_size, filter_size, train_images[train], train_labels[train], train_images[val], train_labels[val], C, loss, accuracy))
      p.start()
      p.join()
      results["HYP_LAST_LOSSES"][i][j].append(loss.value)
      after = datetime.now()

      results["HYP_LAST_TIME"] += (after - before).total_seconds() / 60
      with open("/content/drive/MyDrive/CIFAR10relu.pickle", "wb") as file:
        pickle.dump(results, file, protocol = pickle.HIGHEST_PROTOCOL)

# %%
C_best = np.array(Cs)[np.argmin(np.mean(results["HYP_LAST_LOSSES"], axis = 0), axis = -1)]
print(C_best)
print(results["HYP_LAST_TIME"])
# Out:
# [0.001 0.001 0.001 0.001 0.001]
# 12.30390413333333

# %%
# optimize full model hyperparams:
for i, (train, val) in enumerate(results["HYP_FULL_SPLITS"]):

  if len(results["HYP_FULL_LOSSES"]) <= i:
    results["HYP_FULL_LOSSES"].append([])

  for j, filter_size in enumerate(filter_sizes):

    if len(results["HYP_FULL_LOSSES"][i]) <= j:
      results["HYP_FULL_LOSSES"][i].append([])
    
    # train full models:
    for k, bs in enumerate(batch_sizes):

      if len(results["HYP_FULL_LOSSES"][i][j]) <= k:
        results["HYP_FULL_LOSSES"][i][j].append([])
      
      for l, de in enumerate(decay_epochs):

        if len(results["HYP_FULL_LOSSES"][i][j][k]) > l:
          continue

        before = datetime.now()
        loss = Value("d", math.inf)
        accuracy = Value("d", 0.)
        p = Process(target = full_model_eval, args = (input_size, filter_size, train_images[train], train_labels[train], train_images[val], train_labels[val], de, bs, loss, accuracy))
        p.start()
        p.join()
        results["HYP_FULL_LOSSES"][i][j][k].append(loss.value)
        after = datetime.now()

        results["HYP_FULL_TIME"] += (after - before).total_seconds() / 60
        with open("/content/drive/MyDrive/CIFAR10relu.pickle", "wb") as file:
          pickle.dump(results, file, protocol = pickle.HIGHEST_PROTOCOL)

# %%
means = np.mean(results["HYP_FULL_LOSSES"], axis = 0)
indices = np.argmin(means.reshape((means.shape[0], -1)), axis = -1)
indices = np.unravel_index(indices, means.shape[1:])
batch_size_best = np.array(batch_sizes)[indices[0]]
decay_epochs_best = np.array(decay_epochs)[indices[1]]
print(batch_size_best)
print(decay_epochs_best)
print(results["HYP_FULL_TIME"])
# Out:
# [16 16 16 16 16]
# [500  25  25  25  25]
# 323.00586001666727

# %%
# optimize hyperparameters:
repetitions = 100

for i, filter_size in enumerate(filter_sizes):

  if len(results["LAST_LOSSES"]) <= i:
    results["LAST_LOSSES"].append([])
  if len(results["FULL_LOSSES"]) <= i:
    results["FULL_LOSSES"].append([])

  for j, rep in enumerate(range(repetitions)):

    # shuffle train data:
    indices = np.arange(len(train_labels))
    np.random.shuffle(indices)
    train_images = train_images[indices]
    train_labels = train_labels[indices]

    if len(results["LAST_LOSSES"][i]) <= j:
      # train last layer models:
      before = datetime.now()
      loss = Value("d", math.inf)
      accuracy = Value("d", 0.)
      p = Process(target = last_layer_eval, args = (input_size, filter_size, train_images, train_labels, test_images, test_labels, C_best[i], loss, accuracy))
      p.start()
      p.join()
      results["LAST_LOSSES"][-1].append(loss.value)
      after = datetime.now()
      results["LAST_TIME"] += (after - before).total_seconds()

    if len(results["FULL_LOSSES"][i]) <= j:
      # train full models:
      before = datetime.now()
      loss = Value("d", math.inf)
      accuracy = Value("d", 0.)
      p = Process(target = full_model_eval, args = (input_size, filter_size, train_images, train_labels, test_images, test_labels, decay_epochs_best[i], batch_size_best[i], loss, accuracy))
      p.start()
      p.join()
      results["FULL_LOSSES"][-1].append(loss.value)
      after = datetime.now()
      results["FULL_TIME"] += (after - before).total_seconds()

print(np.mean(results["LAST_LOSSES"], axis = -1))
print(results["FULL_TIME"])
print(np.mean(results["FULL_LOSSES"], axis = -1))
print(results["FULL_TIME"])

with open("/content/drive/MyDrive/CIFAR10relu.pickle", "wb") as file:
  pickle.dump(results, file, protocol = pickle.HIGHEST_PROTOCOL)

# %%
import matplotlib.pyplot as plt

x = np.mean(results["LAST_LOSSES"], axis = -1)
y = np.mean(results["FULL_LOSSES"], axis = -1)
plt.scatter(x, y)
plt.savefig("scatterCIFAR10relu.png")

# %%
# !cp /content/scatterCIFAR10relu.png /content/drive/MyDrive

# %%
from google.colab import runtime

runtime.unassign()
